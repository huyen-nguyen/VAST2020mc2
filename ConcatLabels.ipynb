# %%
import pandas as pd

# %%
file=pd.read_csv("/Users/huyennguyen/Huyen/GitHub/VAST2020mc2/Labels/Person10.csv")

# %%
file
# Out:
#     Image       object   Unnamed: 2     Unnamed: 3   Unnamed: 4  \
# 0       1   partyFavor         sign    lavenderDie    miniCards
# 1       2  cactusPaper          NaN            NaN          NaN
# 2       3  cactusPaper          NaN            NaN          NaN
# 3       4  plaidPencil          NaN            NaN          NaN
# 4       5  plaidPencil          NaN            NaN          NaN
# 5       6  cactusPaper          NaN            NaN          NaN
# 6       7  lavenderDie    miniCards            NaN          NaN
# 7       8  lavenderDie          NaN            NaN          NaN
# 8       9  lavenderDie          NaN            NaN          NaN
# 9      10  lavenderDie          NaN            NaN          NaN
# 10     11  lavenderDie          NaN            NaN          NaN
# 11     12  cactusPaper          NaN            NaN          NaN
# 12     13  cactusPaper          NaN            NaN          NaN
# 13     14  plaidPencil          NaN            NaN          NaN
# ...
